# %%
import os
from constant import openai_key

os.environ["OPENAI_API_KEY"] = openai_key

# %%
from langchain_core.prompts import PromptTemplate

demo_template='''I want you to act as a acting financial advisor for people.
In an easy way, explain the basics of {financial_concept}.'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_core.prompts import ChatPromptTemplate
#       3 demo_template='''I want you to act as a acting financial advisor for people.
#       4 In an easy way, explain the basics of {financial_concept}.'''
#
# ModuleNotFoundError: No module named 'langchain_core'

# %%
prompt=PromptTemplate(
    input_variables=['financial_concept'],
    template=demo_template
    )

prompt.format(financial_concept='income tax')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 prompt=PromptTemplate(
#       2     input_variables=['financial_concept'],
#       3     template=demo_template
#       4     )
#       6 prompt.format(financial_concept='income tax')
#
# NameError: name 'PromptTemplate' is not defined
